# %% [markdown]
# # Assignment

# %% [markdown]
# ## Brief
#
# Write the Python codes for the following questions.

# %% [markdown]
# ## Instructions
#
# - Step 1: Run the followings cell to get connected to your MongoDB. Make sure your credential is in dotenv file.
# - Step 2: Put your answer inside each function. Please do not construct your own function.
# - Step 3: You can test your function under test section.
# - Step 4. Run test my function to confirm if my code is working.

# %% [markdown]
# ### Connections

# %%
import os
import pymongo
import test_solution

from dotenv import load_dotenv
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://jagizv6_db_user:TouYeiv1lu@cluster0.cs4dwfp.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# Load environment variables from .env file
load_dotenv()
MONGODB_URI = os.getenv('MONGODB_URI')
my_password = os.getenv("MONGODB_URI")
print(f"MONGODB_URI:{my_password}")
if not MONGODB_URI:
    raise ValueError(
        "❌ MONGODB_URI not found!\n"
        "Please create a .env file with your MongoDB credentials.\n"
        "See README.md for setup instructions."
    )
client = MongoClient(MONGODB_URI, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("✅ Successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# MONGODB_URI:mongodb+srv://jagizv6_db_user:TouYeiv1lu@cluster0.dxuttlx.mongodb.net/?appName=Cluster0
# ---------------------------------------------------------------------------
# NXDOMAIN                                  Traceback (most recent call last)
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/srv_resolver.py:88, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#      87 try:
# ---> 88     results = _resolve('_mongodb._tcp.' + self.__fqdn, 'SRV',
#      89                        lifetime=self.__connect_timeout)
#      90 except Exception as exc:
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/srv_resolver.py:48, in _resolve(*args, **kwargs)
#      47 # dnspython 1.X
# ---> 48 return resolver.query(*args, **kwargs)
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/dns/resolver.py:1100, in query(qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime)
#    1091 """Query nameservers to find the answer to the question.
#    1092
#    1093 This is a convenience function that uses the default resolver
#    (...)   1097 parameters.
#    1098 """
# -> 1100 return get_default_resolver().query(qname, rdtype, rdclass, tcp, source,
#    1101                                     raise_on_no_answer, source_port,
#    1102                                     lifetime)
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/dns/resolver.py:1002, in Resolver.query(self, qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime)
#    1001 if all_nxdomain:
# -> 1002     raise NXDOMAIN(qnames=qnames_to_try, responses=nxdomain_responses)
#    1003 answer = Answer(_qname, rdtype, rdclass, response,
#    1004                 raise_on_no_answer)
#
# NXDOMAIN: None of DNS query names exist: _mongodb._tcp.cluster0.dxuttlx.mongodb.net., _mongodb._tcp.cluster0.dxuttlx.mongodb.net.
#
# During handling of the above exception, another exception occurred:
#
# ConfigurationError                        Traceback (most recent call last)
# Cell In[14], line 12
#       6 if not MONGODB_URI:
#       7     raise ValueError(
#       8         "❌ MONGODB_URI not found!\n"
#       9         "Please create a .env file with your MongoDB credentials.\n"
#      10         "See README.md for setup instructions."
#      11     )
# ---> 12 client = MongoClient(MONGODB_URI, server_api=ServerApi('1'))
#      13 # Send a ping to confirm a successful connection
#      14 try:
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/mongo_client.py:670, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     667 if timeout is not None:
#     668     timeout = common.validate_timeout_or_none_or_zero(
#     669         keyword_opts.cased_key("connecttimeoutms"), timeout)
# --> 670 res = uri_parser.parse_uri(
#     671     entity, port, validate=True, warn=True, normalize=False,
#     672     connect_timeout=timeout)
#     673 seeds.update(res["nodelist"])
#     674 username = res["username"] or username
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/uri_parser.py:524, in parse_uri(uri, default_port, validate, warn, normalize, connect_timeout)
#     522 connect_timeout = connect_timeout or options.get("connectTimeoutMS")
#     523 dns_resolver = _SrvResolver(fqdn, connect_timeout=connect_timeout)
# --> 524 nodes = dns_resolver.get_hosts()
#     525 dns_options = dns_resolver.get_options()
#     526 if dns_options:
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/srv_resolver.py:118, in _SrvResolver.get_hosts(self)
#     117 def get_hosts(self):
# --> 118     _, nodes = self._get_srv_response_and_hosts(True)
#     119     return nodes
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/srv_resolver.py:99, in _SrvResolver._get_srv_response_and_hosts(self, encapsulate_errors)
#      98 def _get_srv_response_and_hosts(self, encapsulate_errors):
# ---> 99     results = self._resolve_uri(encapsulate_errors)
#     101     # Construct address tuples
#     102     nodes = [
#     103         (maybe_decode(res.target.to_text(omit_final_dot=True)), res.port)
#     104         for res in results]
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/srv_resolver.py:95, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#      93         raise
#      94     # Else, raise all errors as ConfigurationError.
# ---> 95     raise ConfigurationError(str(exc))
#      96 return results
#
# ConfigurationError: None of DNS query names exist: _mongodb._tcp.cluster0.dxuttlx.mongodb.net., _mongodb._tcp.cluster0.dxuttlx.mongodb.net.

# %%
db = client.sample_mflix
movies = db.movies
print(f"📊 Database: {db.name}")
print(f"📁 Collection: movies ({movies.count_documents({})} documents)")
# Out:
# 📊 Database: sample_mflix
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[4], line 4
#       2 movies = db.movies
#       3 print(f"📊 Database: {db.name}")
# ----> 4 print(f"📁 Collection: movies ({movies.count_documents({})} documents)")
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/collection.py:2163, in Collection.count_documents(self, filter, session, comment, **kwargs)
#    2160         return 0
#    2161     return result["n"]
# -> 2163 return self._retryable_non_cursor_read(_cmd, session, _Op.COUNT)
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/collection.py:2177, in Collection._retryable_non_cursor_read(self, func, session, operation)
#    2175 client = self._database.client
#    2176 with client._tmp_session(session) as s:
# -> 2177     return client._retryable_read(func, self._read_preference_for(s), s, operation)
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)   1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)   2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:2912, in _ClientConnectionRetryable._read(self)
#    2910 self._server = self._get_server()
#    2911 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2912 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2913     conn,
#    2914     read_pref,
#    2915 ):
#    2916     if self._retrying and not self._retryable:
#    2917         self._check_last_error()
#
# File ~/miniconda3/envs/bde/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1867, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1858 # Get a connection for a server matching the read preference, and yield
#    1859 # conn with the effective read preference. The Server Selection
#    1860 # Spec says not to send any $readPreference to standalones and to
#    (...)   1864 # NOTE: We already opened the Topology when selecting a server so there's no need
#    1865 # to call _get_topology() again.
#    1866 single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1867 with self._checkout(server, session) as conn:
#    1868     if single:
#    1869         if conn.is_repl and not (session and session.in_transaction):
#    1870             # Use primary preferred to ensure any repl set member
#    1871             # can handle the request.
#
# File ~/miniconda3/envs/bde/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/mongo_client.py:1777, in MongoClient._checkout(self, server, session)
#    1775     yield session._pinned_connection
#    1776     return
# -> 1777 with server.checkout(handler=err_handler) as conn:
#    1778     # Pin this session to the selected server or connection.
#    1779     if (
#    1780         in_txn
#    1781         and session
#    (...)   1786         )
#    1787     ):
#    1788         session._pin(server, conn)
#
# File ~/miniconda3/envs/bde/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/pool.py:1118, in Pool.checkout(self, handler)
#    1109 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1110     _debug_log(
#    1111         _CONNECTION_LOGGER,
#    1112         message=_ConnectionStatusMessage.CHECKOUT_STARTED,
#    (...)   1115         serverPort=self.address[1],
#    1116     )
# -> 1118 conn = self._get_conn(checkout_started_time, handler=handler)
#    1120 duration = time.monotonic() - checkout_started_time
#    1121 if self.enabled_for_cmap:
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/pool.py:1280, in Pool._get_conn(self, checkout_started_time, handler)
#    1278 else:  # We need to create a new connection
#    1279     try:
# -> 1280         conn = self.connect(handler=handler)
#    1281     finally:
#    1282         with self._max_connecting_cond:
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/pool.py:1072, in Pool.connect(self, handler)
#    1069     if handler:
#    1070         handler.contribute_socket(conn, completed_handshake=False)
# -> 1072     conn.authenticate()
#    1073 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1074 except BaseException:
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/pool.py:525, in Connection.authenticate(self, reauthenticate)
#     522 if creds:
#     523     from pymongo.synchronous import auth
# --> 525     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     526 self.ready = True
#     527 duration = time.monotonic() - self.creation_time
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/auth.py:450, in authenticate(credentials, conn, reauthenticate)
#     448     _authenticate_oidc(credentials, conn, reauthenticate)
#     449 else:
# --> 450     auth_func(credentials, conn)
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/auth.py:355, in _authenticate_default(credentials, conn)
#     353         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354     else:
# --> 355         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356 else:
#     357     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/auth.py:135, in _authenticate_scram(credentials, conn, mechanism)
#     128 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     130 cmd = {
#     131     "saslContinue": 1,
#     132     "conversationId": res["conversationId"],
#     133     "payload": Binary(client_final),
#     134 }
# --> 135 res = conn.command(source, cmd)
#     137 parsed = _parse_scram_response(res["payload"])
#     138 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,  # type: ignore[arg-type]
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/synchronous/network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File ~/miniconda3/envs/bde/lib/python3.13/site-packages/pymongo/helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# ### Question 1
#
# Question: From the `movies` collection, return the documents with the `plot` that starts with `"war"` in acending order of released date, print only title, plot and released fields. Limit the result to 5.

# %% [markdown]
# **Answer:**

# %%
# ============================================================================
# Question 1
# ============================================================================
def war_movies(movies_collection):
    """
    Enter Your Solution Here
    """
    results = []
    
    # Start your solutions


    



    # Your solution ends here
    
    return results

# %%
## Test Your Function Here
war_movies(movies)
# Out:
# [{'title': 'Nausicaè of the Valley of the Wind',
#   'plot': 'Warrior/pacifist Princess Nausicaè desperately struggles to prevent two warring nations from destroying themselves and their dying planet.',
#   'released': datetime.datetime(1984, 3, 11, 0, 0)},
#  {'title': 'Nausicaè of the Valley of the Wind',
#   'plot': 'Warrior/pacifist Princess Nausicaè desperately struggles to prevent two warring nations from destroying themselves and their dying planet.',
#   'released': datetime.datetime(1984, 3, 11, 0, 0)},
#  {'title': 'Heaven and Earth',
#   'plot': 'Warlords Kagetora and Takeda each wish to prevent the other from gaining hegemony in feudal Japan. The two samurai leaders pursue one another across the countryside, engaging in massive ...',
#   'released': datetime.datetime(1991, 2, 8, 0, 0)},
#  {'title': 'Under the Stars',
#   'plot': 'Warning! This synopsis contains spoilers Bajo las estrellas (beneath the stars) features the selfish...',
#   'released': datetime.datetime(2007, 6, 15, 0, 0)},
#  {'title': 'Aliens vs. Predator: Requiem',
#   'plot': 'Warring alien and predator races descend on a small town, where unsuspecting residents must band together for any chance of survival.',
#   'released': datetime.datetime(2007, 12, 25, 0, 0)}]

# %% [markdown]
# #### Validating My Solution

# %%
# ============================================================================
# Checking Question 1
# ============================================================================
passed, failed, results = test_solution.TestQuestion1.run_all_tests(war_movies, movies)
# Out:
# ======================================================================
# QUESTION 1: War Movies Query
# ======================================================================
# ✅ PASSED: Function exists
# ✅ PASSED: Returns list
# ✅ PASSED: Returns 5 or fewer results
# ✅ PASSED: Correct fields returned
# ✅ PASSED: Plots start with 'war'
# ✅ PASSED: Sorted by released (ascending)
# ✅ PASSED: No non-war plots
# ✅ PASSED: Compare with correct query
# ======================================================================
# RESULTS: 8 passed, 0 failed
# ======================================================================

# %% [markdown]
# ### Question 2
#
# Question: Group by `rated` and count the number of movies in each.

# %% [markdown]
# **Answer:**

# %%
# ============================================================================
# Question 2
# ============================================================================
def group_by_rated(movies_collection):
    """
    Group by rated and count the number of movies in each.
    """
    results = []
    
    # Start your solution




    # End your solution
    
    return results

# %%
## Test Your Function Here
group_by_rated(movies)
# Out:
# [{'_id': None, 'movie_count': 9894},
#  {'_id': 'PG', 'movie_count': 1852},
#  {'_id': 'APPROVED', 'movie_count': 709},
#  {'_id': 'TV-G', 'movie_count': 59},
#  {'_id': 'AO', 'movie_count': 3},
#  {'_id': 'OPEN', 'movie_count': 1},
#  {'_id': 'TV-14', 'movie_count': 89},
#  {'_id': 'M', 'movie_count': 37},
#  {'_id': 'Approved', 'movie_count': 5},
#  {'_id': 'GP', 'movie_count': 44},
#  {'_id': 'PASSED', 'movie_count': 181},
#  {'_id': 'R', 'movie_count': 5537},
#  {'_id': 'Not Rated', 'movie_count': 1},
#  {'_id': 'G', 'movie_count': 477},
#  {'_id': 'TV-MA', 'movie_count': 60},
#  {'_id': 'TV-PG', 'movie_count': 76},
#  {'_id': 'TV-Y7', 'movie_count': 3},
#  {'_id': 'PG-13', 'movie_count': 2321}]

# %% [markdown]
# #### Validation My Solution

# %%
# ============================================================================
# Checking Question 2
# ============================================================================
passed, failed, results = test_solution.TestQuestion2.run_all_tests(group_by_rated, movies)
# Out:
# ======================================================================
# QUESTION 2: Group by Rated
# ======================================================================
# ✅ PASSED: Function exists
# ✅ PASSED: Returns list
# ✅ PASSED: Returns results
# ✅ PASSED: Result structure
# ✅ PASSED: Counts are positive
# ✅ PASSED: Total count matches
# ✅ PASSED: Includes common ratings
# ✅ PASSED: Compare with correct implementation
# ======================================================================
# RESULTS: 8 passed, 0 failed
# ======================================================================

# %% [markdown]
# ### Question 3
#
# Question: Count the number of movies with 3 comments or more.

# %% [markdown]
# **Answer:**

# %%
# ============================================================================
# Question 3
# ============================================================================
def count_movies_with_comments(movies_collection):
    """
    Count the number of movies with 3 comments or more.
    """
    count = 0
    
    # Start your solution


    # End your solution
    
    return count

# %%
## Test Your Function Here
count_movies_with_comments(movies)
# Out:
# 385

# %%
# ============================================================================
# Checking Question 3
# ============================================================================
passed, failed, results = test_solution.TestQuestion3.run_all_tests(count_movies_with_comments, movies)
# Out:
# ======================================================================
# QUESTION 3: Count Movies with 3+ Comments
# ======================================================================
# ✅ PASSED: Function exists
# ✅ PASSED: Returns integer
# ✅ PASSED: Returns positive count
# ✅ PASSED: Count is reasonable
# ✅ PASSED: Compare with correct query
# ✅ PASSED: Boundary case (exactly 3)
# ======================================================================
# RESULTS: 6 passed, 0 failed
# ======================================================================
